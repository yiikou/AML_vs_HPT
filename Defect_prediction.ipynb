# %%
import azureml.core

print("This notebook was created using version 1.0.23 of the Azure ML SDK")
print("You are currently using version", azureml.core.VERSION, "of the Azure ML SDK")
# Out:
# This notebook was created using version 1.0.23 of the Azure ML SDK
# You are currently using version 1.0.39 of the Azure ML SDK

# %%
import os

subscription_id = os.getenv("SUBSCRIPTION_ID", default="942813ed-26a2-4790-9097-d4be7560fce0")
resource_group = os.getenv("RESOURCE_GROUP", default="ICSE-tutorial")
workspace_name = os.getenv("WORKSPACE_NAME", default="workspace_fresher")
workspace_region = os.getenv("WORKSPACE_REGION", default="eastus2")

# %%
from azureml.core import Workspace

try:
    ws = Workspace(subscription_id = subscription_id, resource_group = resource_group, workspace_name = workspace_name)
    # write the details of the workspace to a configuration file to the notebook library
    ws.write_config()
    print("Workspace configuration succeeded.")
except:
    print("Workspace not accessible.")
# Out:
# Workspace configuration succeeded.

# %% [markdown]
# ### Create compute resources for your training experiments
#
# Many of the sample notebooks use Azure ML managed compute (AmlCompute) to train models using a dynamically scalable pool of compute. In this section you will create default compute clusters for use by the other notebooks and any other operations you choose.
#
# To create a cluster, you need to specify a compute configuration that specifies the type of machine to be used and the scalability behaviors.  Then you choose a name for the cluster that is unique within the workspace that can be used to address the cluster later.
#
# The cluster parameters are:
# * vm_size - this describes the virtual machine type and size used in the cluster.  All machines in the cluster are the same type.  You can get the list of vm sizes available in your region by using the CLI command
#
# ```shell
# az vm list-skus -o tsv
# ```
# * min_nodes - this sets the minimum size of the cluster.  If you set the minimum to 0 the cluster will shut down all nodes while note in use.  Setting this number to a value higher than 0 will allow for faster start-up times, but you will also be billed when the cluster is not in use.
# * max_nodes - this sets the maximum size of the cluster.  Setting this to a larger number allows for more concurrency and a greater distributed processing of scale-out jobs.
#
#
# To create a **CPU** cluster now, run the cell below. The autoscale settings mean that the cluster will scale down to 0 nodes when inactive and up to 4 nodes when busy.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Choose a name for your CPU cluster
cpu_cluster_name = "cpucluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print("Found existing cpucluster")
except ComputeTargetException:
    print("Creating new cpucluster")
    
    # Specify the configuration for the new cluster
    compute_config = AmlCompute.provisioning_configuration(vm_size="STANDARD_D2_V2",
                                                           min_nodes=0,
                                                           max_nodes=4)

    # Create the cluster with the specified name and configuration
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)
    
    # Wait for the cluster to complete, show the output log
    cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cpucluster

# %%
import azureml.dataprep as dprep

# %% [markdown]
# # Load data
# Download two different NYC Taxi data sets into dataflow objects. These datasets contain slightly different fields. The method auto_read_file() automatically recognizes the input file type.

# %%
from IPython.display import display
import os
eclipse_2_0_raw = dprep.read_csv(path=os.path.join(os.getcwd(), "defect_eclipse_2_0.csv"), header=dprep.PromoteHeadersMode.GROUPED)

#eclipse_2_0_raw=eclipse_2_0_raw.drop_columns('Column1')
display(eclipse_2_0_raw.head(5))
# Out:
#   pre ACD          FOUT_avg FOUT_max FOUT_sum          MLOC_avg MLOC_max  \
# 0   1   0              6.75       29       54              9.25       32
# 1   1   0              12.5       13       25                16       18
# 2   0   0  5.33333333333333       10       16  12.6666666666667       29
# 3   2   0  7.33333333333333       16       88  9.66666666666667       28
# 4   2   4  6.21052631578947       27      118  9.89473684210526       55
#
#   MLOC_sum           NBD_avg NBD_max  ...   NSM_max NSM_sum  \
# 0       74              1.75       5  ...         0       0
# 1       32                 2       3  ...         0       0
# 2       38                 3       6  ...         0       0
# 3      116  2.08333333333333       5  ...         0       0
# 4      188  1.78947368421053       4  ...         1       1
#
#              PAR_avg PAR_max PAR_sum TLOC            CC_avg CC_max CC_sum  \
# 0                  2       4      16  128             2.875      7     23
# 1                  3       4       6   55                 4      4      8
# 2                  1       2       3   70  4.33333333333333      9     13
# 3   1.33333333333333       2      16  174  2.83333333333333      8     34
# 4  0.578947368421053       2      11  277  2.42105263157895     11     46
#
#     post
# 0  FALSE
# 1  FALSE
# 2  FALSE
# 3  FALSE
# 4  FALSE
#
# [5 rows x 33 columns]

# %%
eclipse_2_0_raw.get_profile()
# Out:
# ColumnProfile:
#     column_name: pre
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 36
#
#
# ColumnProfile:
#     column_name: ACD
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
# ColumnProfile:
#     column_name: FOUT_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 9.92857142857143
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
# ColumnProfile:
#     column_name: FOUT_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 97
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 108
#
#
# ColumnProfile:
#     column_name: FOUT_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 378
#
#
# ColumnProfile:
#     column_name: MLOC_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 96.1666666666667
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
# ColumnProfile:
#     column_name: MLOC_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 994
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 178
#
#
# ColumnProfile:
#     column_name: MLOC_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 998
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 563
#
#
# ColumnProfile:
#     column_name: NBD_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 7
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 694
#
#
# ColumnProfile:
#     column_name: NBD_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 13
#
#
# ColumnProfile:
#     column_name: NBD_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 175
#
#
# ColumnProfile:
#     column_name: NOF_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 114
#
#
# ColumnProfile:
#     column_name: NOF_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 54
#
#
# ColumnProfile:
#     column_name: NOF_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 60
#
#
# ColumnProfile:
#     column_name: NOI
#     type: FieldType.STRING
#
#     min: 0
#     max: 1
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
# ColumnProfile:
#     column_name: NOM_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 92
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 186
#
#
# ColumnProfile:
#     column_name: NOM_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 92
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 103
#
#
# ColumnProfile:
#     column_name: NOM_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 92
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 110
#
#
# ColumnProfile:
#     column_name: NOT
#     type: FieldType.STRING
#
#     min: 0
#     max: 2
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
# ColumnProfile:
#     column_name: NSF_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 95
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 120
#
#
# ColumnProfile:
#     column_name: NSF_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 95
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 76
#
#
# ColumnProfile:
#     column_name: NSF_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 95
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 77
#
#
# ColumnProfile:
#     column_name: NSM_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 73
#
#
# ColumnProfile:
#     column_name: NSM_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
# ColumnProfile:
#     column_name: NSM_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
# ColumnProfile:
#     column_name: PAR_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 8
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 732
#
#
# ColumnProfile:
#     column_name: PAR_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
# ColumnProfile:
#     column_name: PAR_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 98
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 138
#
#
# ColumnProfile:
#     column_name: TLOC
#     type: FieldType.STRING
#
#     min: 10
#     max: 993
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 685
#
#
# ColumnProfile:
#     column_name: CC_avg
#     type: FieldType.STRING
#
#     min: 0
#     max: 9.94736842105263
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
# ColumnProfile:
#     column_name: CC_max
#     type: FieldType.STRING
#
#     min: 0
#     max: 9
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 74
#
#
# ColumnProfile:
#     column_name: CC_sum
#     type: FieldType.STRING
#
#     min: 0
#     max: 99
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 268
#
#
# ColumnProfile:
#     column_name: post
#     type: FieldType.STRING
#
#     min: FALSE
#     max: TRUE
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2

# %%
type_infer = eclipse_2_0_raw.builders.set_column_types()
type_infer.learn()
type_infer
# Out:
# Column types conversion candidates:
# 'FOUT_max': [FieldType.INTEGER],
# 'MLOC_max': [FieldType.INTEGER],
# 'NBD_max': [FieldType.INTEGER],
# 'NOF_sum': [FieldType.INTEGER],
# 'NOT': [FieldType.INTEGER],
# 'NSM_avg': [FieldType.DECIMAL],
# 'PAR_max': [FieldType.INTEGER],
# 'CC_max': [FieldType.INTEGER],
# 'FOUT_avg': [FieldType.DECIMAL],
# 'MLOC_sum': [FieldType.INTEGER],
# 'NOF_avg': [FieldType.DECIMAL],
# 'NOM_avg': [FieldType.DECIMAL],
# 'NSF_avg': [FieldType.DECIMAL],
# 'NSM_max': [FieldType.INTEGER],
# 'PAR_sum': [FieldType.INTEGER],
# 'CC_sum': [FieldType.INTEGER],
# 'pre': [FieldType.INTEGER],
# 'MLOC_avg': [FieldType.DECIMAL],
# 'NBD_sum': [FieldType.INTEGER],
# 'NOI': [FieldType.INTEGER],
# 'NOM_sum': [FieldType.INTEGER],
# 'NSF_sum': [FieldType.INTEGER],
# 'PAR_avg': [FieldType.DECIMAL],
# 'CC_avg': [FieldType.DECIMAL],
# 'ACD': [FieldType.INTEGER],
# 'FOUT_sum': [FieldType.INTEGER],
# 'NBD_avg': [FieldType.DECIMAL],
# 'NOF_max': [FieldType.INTEGER],
# 'NOM_max': [FieldType.INTEGER],
# 'NSF_max': [FieldType.INTEGER],
# 'NSM_sum': [FieldType.INTEGER],
# 'TLOC': [FieldType.INTEGER],
# 'post': [FieldType.BOOLEAN]

# %%
type_converted_df = type_infer.to_dataflow()
type_converted_df.get_profile()
# Out:
# ColumnProfile:
#     column_name: pre
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 69.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 36
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 5.0
#           99%: 13.383141711229952
#         99.9%: 31.82188888888868
#
#     mean: 1.1346411056620556
#     std: 2.8891535024127517
#     variance: 8.34720796050387
#     skewness: 7.232636911635785
#     kurtosis: 91.22436494033164
#
# ColumnProfile:
#     column_name: ACD
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 24.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 3.0
#           99%: 7.1061403508771965
#         99.9%: 14.308619047618906
#
#     mean: 0.4235399019170755
#     std: 1.4416366334990331
#     variance: 2.0783161830464256
#     skewness: 5.6888166399064835
#     kurtosis: 45.01289510002426
#
# ColumnProfile:
#     column_name: FOUT_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 51.6190476190476
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.9809684405767953
#           75%: 4.254309856132502
#           95%: 9.039903255616059
#           99%: 14.608855614453578
#         99.9%: 27.912339780219554
#
#     mean: 2.8618049600145703
#     std: 3.395339276916808
#     variance: 11.528328805373953
#     skewness: 2.643080466160554
#     kurtosis: 15.284330568036196
#
# ColumnProfile:
#     column_name: FOUT_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 310.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 108
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 5.986513217047293
#           75%: 14.438946759259256
#           95%: 36.794406444748404
#           99%: 68.26875324675325
#         99.9%: 160.1385833333254
#
#     mean: 10.5305394560856
#     std: 15.555536911916004
#     variance: 241.9747286179813
#     skewness: 4.936570782305539
#     kurtosis: 53.761804720937896
#
# ColumnProfile:
#     column_name: FOUT_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2168.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 378
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 12.474289674289675
#           75%: 43.089175257731966
#           95%: 176.00161830357115
#           99%: 396.8113299663301
#         99.9%: 944.1445555555428
#
#     mean: 40.70708872046367
#     std: 87.05310684516284
#     variance: 7578.243411395339
#     skewness: 7.430825768395453
#     kurtosis: 106.79471719809686
#
# ColumnProfile:
#     column_name: MLOC_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 96.1666666666667
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 4.036377911424477
#           75%: 8.048282562465738
#           95%: 16.719925679584524
#           99%: 30.096464975353854
#         99.9%: 66.08278082010486
#
#     mean: 5.60118367064674
#     std: 6.57138363360546
#     variance: 43.18308286001769
#     skewness: 3.4524868087777367
#     kurtosis: 25.67677155440988
#
# ColumnProfile:
#     column_name: MLOC_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 994.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 178
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 10.974299516908212
#           75%: 26.48688524590164
#           95%: 70.61234575020175
#           99%: 131.66699633699636
#         99.9%: 424.060416666656
#
#     mean: 20.284737702481724
#     std: 33.70512042803107
#     variance: 1136.0351430680776
#     skewness: 8.867455770247998
#     kurtosis: 168.15307471556716
#
# ColumnProfile:
#     column_name: MLOC_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 4559.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 563
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.9031593406593403
#           50%: 25.572598973607036
#           75%: 81.68515840220383
#           95%: 327.83024456521696
#           99%: 744.9001904761906
#         99.9%: 2190.5822499999713
#
#     mean: 79.65968197354755
#     std: 179.78006144238964
#     variance: 32320.870492229395
#     skewness: 8.718406463005655
#     kurtosis: 135.98089231936558
#
# ColumnProfile:
#     column_name: NBD_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 7.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 694
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.251167118409169
#           75%: 1.6761480664733688
#           95%: 2.4605142287560184
#           99%: 3.333827257297741
#         99.9%: 4.763904761904737
#
#     mean: 1.2293923358741883
#     std: 0.7898525671158565
#     variance: 0.6238670777795087
#     skewness: 0.2798597031385416
#     kurtosis: 1.1776330940549
#
# ColumnProfile:
#     column_name: NBD_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 17.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 13
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 2.0
#           75%: 3.954630160550458
#           95%: 6.0
#           99%: 7.478823529411766
#         99.9%: 10.0
#
#     mean: 2.3300639025115304
#     std: 1.883731278712182
#     variance: 3.5484435303986324
#     skewness: 0.7920912500708038
#     kurtosis: 0.8420974786124704
#
# ColumnProfile:
#     column_name: NBD_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 646.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 175
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 7.992299465240641
#           75%: 18.04263157894737
#           95%: 60.177731092436964
#           99%: 123.55484615384619
#         99.9%: 284.34233333333003
#
#     mean: 15.939664140288317
#     std: 27.42106145144289
#     variance: 751.9146111238072
#     skewness: 6.667871569284104
#     kurtosis: 90.19683442806465
#
# ColumnProfile:
#     column_name: NOF_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 114
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 3.0286627735068
#           95%: 9.442187499999974
#           99%: 18.50886153846154
#         99.9%: 73.86764761904635
#
#     mean: 2.6304689626022775
#     std: 6.138766929491907
#     variance: 37.6844594146235
#     skewness: 18.504437300970366
#     kurtosis: 604.2153147337227
#
# ColumnProfile:
#     column_name: NOF_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 54
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 4.0
#           95%: 10.895683890577503
#           99%: 22.30400000000001
#         99.9%: 74.0964444444432
#
#     mean: 2.9271808589686374
#     std: 6.553701137979919
#     variance: 42.950998605959285
#     skewness: 15.670961954384037
#     kurtosis: 465.4404746019681
#
# ColumnProfile:
#     column_name: NOF_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 60
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 4.0
#           95%: 11.701457725947497
#           99%: 24.046666666666674
#         99.9%: 77.16966666666555
#
#     mean: 3.0701441521771415
#     std: 6.840623350112143
#     variance: 46.794127818099476
#     skewness: 14.288054566284915
#     kurtosis: 395.597345221896
#
# ColumnProfile:
#     column_name: NOI
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.1581215633823747
#     std: 0.36488206370873055
#     variance: 0.1331389204163421
#     skewness: 1.8736335045937307
#     kurtosis: 1.5107270856834596
#
# ColumnProfile:
#     column_name: NOM_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 186
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.0
#           75%: 10.168516257721917
#           95%: 28.641724245253624
#           99%: 62.84552769070011
#         99.9%: 184.85577777777462
#
#     mean: 8.78114534942444
#     std: 13.739598903683076
#     variance: 188.7765780340892
#     skewness: 7.140852284592048
#     kurtosis: 89.3893916855781
#
# ColumnProfile:
#     column_name: NOM_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 103
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.0
#           75%: 11.0
#           95%: 31.94922833649585
#           99%: 66.04384615384616
#         99.9%: 190.12511111110882
#
#     mean: 9.514786743944105
#     std: 14.947623473011685
#     variance: 223.4314474909299
#     skewness: 6.4988769142083385
#     kurtosis: 72.1260271150533
#
# ColumnProfile:
#     column_name: NOM_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 110
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.575165841352893
#           75%: 11.804576730608842
#           95%: 33.81511627906973
#           99%: 68.16784117647059
#         99.9%: 196.93133333333208
#
#     mean: 9.95972655669487
#     std: 15.750149037179016
#     variance: 248.06719469335107
#     skewness: 6.362053758504851
#     kurtosis: 68.74884683388954
#
# ColumnProfile:
#     column_name: NOT
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.8423242680933267
#     std: 0.365685153455322
#     variance: 0.13372563145764238
#     skewness: -1.8508478437825182
#     kurtosis: 1.5250839843783988
#
# ColumnProfile:
#     column_name: NSF_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 120
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 7.0
#           99%: 25.281921568627464
#         99.9%: 210.88559999999634
#
#     mean: 2.1323583423561168
#     std: 18.41894196934275
#     variance: 339.25742327001575
#     skewness: 35.528161748324365
#     kurtosis: 1716.5722513981682
#
# ColumnProfile:
#     column_name: NSF_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 76
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 8.0
#           99%: 28.69457142857144
#         99.9%: 210.88559999999634
#
#     mean: 2.2967751523257545
#     std: 18.508507620636646
#     variance: 342.5648543431648
#     skewness: 35.01108423993234
#     kurtosis: 1682.353447120943
#
# ColumnProfile:
#     column_name: NSF_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 77
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 8.0
#           99%: 28.69457142857144
#         99.9%: 210.88559999999634
#
#     mean: 2.3013820775746674
#     std: 18.513744601555416
#     variance: 342.7587391716223
#     skewness: 34.9836907095536
#     kurtosis: 1680.429077368083
#
# ColumnProfile:
#     column_name: NSM_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 73
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.001970284237726
#           99%: 14.613046218487398
#         99.9%: 180.31137142855115
#
#     mean: 1.1298398073253175
#     std: 13.547686314697605
#     variance: 183.53980448144478
#     skewness: 32.856010231782314
#     kurtosis: 1183.845374646725
#
# ColumnProfile:
#     column_name: NSM_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.364838709677399
#           99%: 14.8205701754386
#         99.9%: 180.31137142855115
#
#     mean: 1.1878436617625217
#     std: 13.581461218313104
#     variance: 184.45608882454286
#     skewness: 32.613402524465194
#     kurtosis: 1171.5845655904295
#
# ColumnProfile:
#     column_name: NSM_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.43734374999998
#           99%: 14.8205701754386
#         99.9%: 180.31137142855115
#
#     mean: 1.1903700401248323
#     std: 13.582153780044795
#     variance: 184.47490130478513
#     skewness: 32.607977849294876
#     kurtosis: 1171.320966458119
#
# ColumnProfile:
#     column_name: PAR_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 8.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 732
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0029667075163398774
#            5%: 0.0
#           25%: 0.5
#           50%: 0.8454996451273977
#           75%: 1.1999059641565253
#           95%: 2.2301460864096208
#           99%: 3.4493544117647055
#         99.9%: 6.436676959231013
#
#     mean: 0.9487546093634606
#     std: 0.7353981553081012
#     variance: 0.5408104468305581
#     skewness: 2.0857932435968167
#     kurtosis: 9.46543236208968
#
# ColumnProfile:
#     column_name: PAR_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 28.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 2.0
#           75%: 3.0
#           95%: 5.0
#           99%: 9.0
#         99.9%: 15.335523809523476
#
#     mean: 2.3189181156189713
#     std: 1.8570174825300885
#     variance: 3.4485139304223877
#     skewness: 2.579992226748053
#     kurtosis: 17.491617764776265
#
# ColumnProfile:
#     column_name: PAR_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1753.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 138
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 5.0
#           75%: 12.0
#           95%: 38.96666666666661
#           99%: 94.38040659340663
#         99.9%: 464.7293499999879
#
#     mean: 11.771882894932396
#     std: 38.95463847269043
#     variance: 1517.463858538013
#     skewness: 25.41542964730973
#     kurtosis: 889.1161956099659
#
# ColumnProfile:
#     column_name: TLOC
#     type: FieldType.INTEGER
#
#     min: 3.0
#     max: 5207.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 685
#
#
#     Quantiles (est.):
#          0.1%: 3.0
#            1%: 7.091656874265572
#            5%: 7.0
#           25%: 17.50581395348837
#           50%: 51.925708699902245
#           75%: 129.13081752410113
#           95%: 439.51853146853097
#           99%: 974.5467272727275
#         99.9%: 2444.1052222222006
#
#     mean: 118.43379402585846
#     std: 219.9818379553363
#     variance: 48392.00903020784
#     skewness: 7.742571166792481
#     kurtosis: 111.32590123966531
#
# ColumnProfile:
#     column_name: CC_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 41.1666666666667
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.6130329776204853
#           75%: 2.6207391268493194
#           95%: 4.895734321901286
#           99%: 8.080244416221035
#         99.9%: 18.46184318681302
#
#     mean: 1.9160172285053987
#     std: 1.8484725279596694
#     variance: 3.4168506866216113
#     skewness: 3.9915822752294794
#     kurtosis: 46.34493475597978
#
# ColumnProfile:
#     column_name: CC_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 310.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 74
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 3.0
#           75%: 7.0
#           95%: 18.827654320987648
#           99%: 36.02213235294118
#         99.9%: 145.4962857142821
#
#     mean: 5.620300193193629
#     std: 10.08126070140086
#     variance: 101.63181732960935
#     skewness: 12.068455534723485
#     kurtosis: 257.34828391052275
#
# ColumnProfile:
#     column_name: CC_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1299.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 268
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 10.0
#           75%: 28.202639116202953
#           95%: 106.47045454545439
#           99%: 246.90803571428572
#         99.9%: 709.4838333333201
#
#     mean: 26.898944865507428
#     std: 57.05642023078911
#     variance: 3255.4350895524008
#     skewness: 8.140081331858646
#     kurtosis: 113.09353955468445
#
# ColumnProfile:
#     column_name: post
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2

# %% [markdown]
# # Data preprocesed
# # ===============================
# # AutoML start

# %%
import azureml.core
import pandas as pd
from azureml.core.workspace import Workspace
import logging
import os

# %%
ws = Workspace.from_config()
# choose a name for the run history container in the workspace
experiment_name = 'automated-ml-classification'
# project folder
project_folder = './automated-ml-classification/eclipse_2.0/selected_features'

output = {}
output['SDK version'] = azureml.core.VERSION
output['Subscription ID'] = ws.subscription_id
output['Workspace'] = ws.name
output['Resource Group'] = ws.resource_group
output['Location'] = ws.location
output['Project Directory'] = project_folder
pd.set_option('display.max_colwidth', -1)
outputDf = pd.DataFrame(data = output, index = [''])
outputDf.T
# Out:
#
# Location           canadacentral
# Project Directory  ./automated-ml-classification/eclipse_2.0/selected_features
# Resource Group     ICSE-tutorial
# SDK version        1.0.39
# Subscription ID    942813ed-26a2-4790-9097-d4be7560fce0
# Workspace          workspace_fresher

# %%
import azureml.dataprep as dprep
dflow_prepared=type_converted_df
dflow_prepared.get_profile()
# Out:
# ColumnProfile:
#     column_name: pre
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 69.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 36
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 5.0
#           99%: 13.383141711229952
#         99.9%: 31.82188888888868
#
#     mean: 1.1346411056620556
#     std: 2.8891535024127517
#     variance: 8.34720796050387
#     skewness: 7.232636911635785
#     kurtosis: 91.22436494033164
#
# ColumnProfile:
#     column_name: ACD
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 24.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 3.0
#           99%: 7.1061403508771965
#         99.9%: 14.308619047618906
#
#     mean: 0.4235399019170755
#     std: 1.4416366334990331
#     variance: 2.0783161830464256
#     skewness: 5.6888166399064835
#     kurtosis: 45.01289510002426
#
# ColumnProfile:
#     column_name: FOUT_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 51.6190476190476
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.9809684405767953
#           75%: 4.254309856132502
#           95%: 9.039903255616059
#           99%: 14.608855614453578
#         99.9%: 27.912339780219554
#
#     mean: 2.8618049600145703
#     std: 3.395339276916808
#     variance: 11.528328805373953
#     skewness: 2.643080466160554
#     kurtosis: 15.284330568036196
#
# ColumnProfile:
#     column_name: FOUT_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 310.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 108
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 5.986513217047293
#           75%: 14.438946759259256
#           95%: 36.794406444748404
#           99%: 68.26875324675325
#         99.9%: 160.1385833333254
#
#     mean: 10.5305394560856
#     std: 15.555536911916004
#     variance: 241.9747286179813
#     skewness: 4.936570782305539
#     kurtosis: 53.761804720937896
#
# ColumnProfile:
#     column_name: FOUT_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2168.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 378
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 12.474289674289675
#           75%: 43.089175257731966
#           95%: 176.00161830357115
#           99%: 396.8113299663301
#         99.9%: 944.1445555555428
#
#     mean: 40.70708872046367
#     std: 87.05310684516284
#     variance: 7578.243411395339
#     skewness: 7.430825768395453
#     kurtosis: 106.79471719809686
#
# ColumnProfile:
#     column_name: MLOC_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 96.1666666666667
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 4.036377911424477
#           75%: 8.048282562465738
#           95%: 16.719925679584524
#           99%: 30.096464975353854
#         99.9%: 66.08278082010486
#
#     mean: 5.60118367064674
#     std: 6.57138363360546
#     variance: 43.18308286001769
#     skewness: 3.4524868087777367
#     kurtosis: 25.67677155440988
#
# ColumnProfile:
#     column_name: MLOC_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 994.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 178
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 10.974299516908212
#           75%: 26.48688524590164
#           95%: 70.61234575020175
#           99%: 131.66699633699636
#         99.9%: 424.060416666656
#
#     mean: 20.284737702481724
#     std: 33.70512042803107
#     variance: 1136.0351430680776
#     skewness: 8.867455770247998
#     kurtosis: 168.15307471556716
#
# ColumnProfile:
#     column_name: MLOC_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 4559.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 563
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.9031593406593403
#           50%: 25.572598973607036
#           75%: 81.68515840220383
#           95%: 327.83024456521696
#           99%: 744.9001904761906
#         99.9%: 2190.5822499999713
#
#     mean: 79.65968197354755
#     std: 179.78006144238964
#     variance: 32320.870492229395
#     skewness: 8.718406463005655
#     kurtosis: 135.98089231936558
#
# ColumnProfile:
#     column_name: NBD_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 7.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 694
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.251167118409169
#           75%: 1.6761480664733688
#           95%: 2.4605142287560184
#           99%: 3.333827257297741
#         99.9%: 4.763904761904737
#
#     mean: 1.2293923358741883
#     std: 0.7898525671158565
#     variance: 0.6238670777795087
#     skewness: 0.2798597031385416
#     kurtosis: 1.1776330940549
#
# ColumnProfile:
#     column_name: NBD_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 17.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 13
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 2.0
#           75%: 3.954630160550458
#           95%: 6.0
#           99%: 7.478823529411766
#         99.9%: 10.0
#
#     mean: 2.3300639025115304
#     std: 1.883731278712182
#     variance: 3.5484435303986324
#     skewness: 0.7920912500708038
#     kurtosis: 0.8420974786124704
#
# ColumnProfile:
#     column_name: NBD_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 646.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 175
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 7.992299465240641
#           75%: 18.04263157894737
#           95%: 60.177731092436964
#           99%: 123.55484615384619
#         99.9%: 284.34233333333003
#
#     mean: 15.939664140288317
#     std: 27.42106145144289
#     variance: 751.9146111238072
#     skewness: 6.667871569284104
#     kurtosis: 90.19683442806465
#
# ColumnProfile:
#     column_name: NOF_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 114
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 3.0286627735068
#           95%: 9.442187499999974
#           99%: 18.50886153846154
#         99.9%: 73.86764761904635
#
#     mean: 2.6304689626022775
#     std: 6.138766929491907
#     variance: 37.6844594146235
#     skewness: 18.504437300970366
#     kurtosis: 604.2153147337227
#
# ColumnProfile:
#     column_name: NOF_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 54
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 4.0
#           95%: 10.895683890577503
#           99%: 22.30400000000001
#         99.9%: 74.0964444444432
#
#     mean: 2.9271808589686374
#     std: 6.553701137979919
#     variance: 42.950998605959285
#     skewness: 15.670961954384037
#     kurtosis: 465.4404746019681
#
# ColumnProfile:
#     column_name: NOF_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 251.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 60
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 1.0
#           75%: 4.0
#           95%: 11.701457725947497
#           99%: 24.046666666666674
#         99.9%: 77.16966666666555
#
#     mean: 3.0701441521771415
#     std: 6.840623350112143
#     variance: 46.794127818099476
#     skewness: 14.288054566284915
#     kurtosis: 395.597345221896
#
# ColumnProfile:
#     column_name: NOI
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.1581215633823747
#     std: 0.36488206370873055
#     variance: 0.1331389204163421
#     skewness: 1.8736335045937307
#     kurtosis: 1.5107270856834596
#
# ColumnProfile:
#     column_name: NOM_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 186
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.0
#           75%: 10.168516257721917
#           95%: 28.641724245253624
#           99%: 62.84552769070011
#         99.9%: 184.85577777777462
#
#     mean: 8.78114534942444
#     std: 13.739598903683076
#     variance: 188.7765780340892
#     skewness: 7.140852284592048
#     kurtosis: 89.3893916855781
#
# ColumnProfile:
#     column_name: NOM_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 103
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.0
#           75%: 11.0
#           95%: 31.94922833649585
#           99%: 66.04384615384616
#         99.9%: 190.12511111110882
#
#     mean: 9.514786743944105
#     std: 14.947623473011685
#     variance: 223.4314474909299
#     skewness: 6.4988769142083385
#     kurtosis: 72.1260271150533
#
# ColumnProfile:
#     column_name: NOM_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 297.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 110
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 1.0
#            5%: 1.0
#           25%: 2.0
#           50%: 5.575165841352893
#           75%: 11.804576730608842
#           95%: 33.81511627906973
#           99%: 68.16784117647059
#         99.9%: 196.93133333333208
#
#     mean: 9.95972655669487
#     std: 15.750149037179016
#     variance: 248.06719469335107
#     skewness: 6.362053758504851
#     kurtosis: 68.74884683388954
#
# ColumnProfile:
#     column_name: NOT
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 2.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 3
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.0
#           75%: 1.0
#           95%: 1.0
#           99%: 1.0
#         99.9%: 1.0
#
#     mean: 0.8423242680933267
#     std: 0.365685153455322
#     variance: 0.13372563145764238
#     skewness: -1.8508478437825182
#     kurtosis: 1.5250839843783988
#
# ColumnProfile:
#     column_name: NSF_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 120
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 7.0
#           99%: 25.281921568627464
#         99.9%: 210.88559999999634
#
#     mean: 2.1323583423561168
#     std: 18.41894196934275
#     variance: 339.25742327001575
#     skewness: 35.528161748324365
#     kurtosis: 1716.5722513981682
#
# ColumnProfile:
#     column_name: NSF_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 76
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 8.0
#           99%: 28.69457142857144
#         99.9%: 210.88559999999634
#
#     mean: 2.2967751523257545
#     std: 18.508507620636646
#     variance: 342.5648543431648
#     skewness: 35.01108423993234
#     kurtosis: 1682.353447120943
#
# ColumnProfile:
#     column_name: NSF_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1049.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 77
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 1.0
#           95%: 8.0
#           99%: 28.69457142857144
#         99.9%: 210.88559999999634
#
#     mean: 2.3013820775746674
#     std: 18.513744601555416
#     variance: 342.7587391716223
#     skewness: 34.9836907095536
#     kurtosis: 1680.429077368083
#
# ColumnProfile:
#     column_name: NSM_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 73
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.001970284237726
#           99%: 14.613046218487398
#         99.9%: 180.31137142855115
#
#     mean: 1.1298398073253175
#     std: 13.547686314697605
#     variance: 183.53980448144478
#     skewness: 32.856010231782314
#     kurtosis: 1183.845374646725
#
# ColumnProfile:
#     column_name: NSM_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.364838709677399
#           99%: 14.8205701754386
#         99.9%: 180.31137142855115
#
#     mean: 1.1878436617625217
#     std: 13.581461218313104
#     variance: 184.45608882454286
#     skewness: 32.613402524465194
#     kurtosis: 1171.5845655904295
#
# ColumnProfile:
#     column_name: NSM_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 596.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 48
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 4.43734374999998
#           99%: 14.8205701754386
#         99.9%: 180.31137142855115
#
#     mean: 1.1903700401248323
#     std: 13.582153780044795
#     variance: 184.47490130478513
#     skewness: 32.607977849294876
#     kurtosis: 1171.320966458119
#
# ColumnProfile:
#     column_name: PAR_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 8.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 732
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0029667075163398774
#            5%: 0.0
#           25%: 0.5
#           50%: 0.8454996451273977
#           75%: 1.1999059641565253
#           95%: 2.2301460864096208
#           99%: 3.4493544117647055
#         99.9%: 6.436676959231013
#
#     mean: 0.9487546093634606
#     std: 0.7353981553081012
#     variance: 0.5408104468305581
#     skewness: 2.0857932435968167
#     kurtosis: 9.46543236208968
#
# ColumnProfile:
#     column_name: PAR_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 28.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 20
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 2.0
#           75%: 3.0
#           95%: 5.0
#           99%: 9.0
#         99.9%: 15.335523809523476
#
#     mean: 2.3189181156189713
#     std: 1.8570174825300885
#     variance: 3.4485139304223877
#     skewness: 2.579992226748053
#     kurtosis: 17.491617764776265
#
# ColumnProfile:
#     column_name: PAR_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1753.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 138
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 5.0
#           75%: 12.0
#           95%: 38.96666666666661
#           99%: 94.38040659340663
#         99.9%: 464.7293499999879
#
#     mean: 11.771882894932396
#     std: 38.95463847269043
#     variance: 1517.463858538013
#     skewness: 25.41542964730973
#     kurtosis: 889.1161956099659
#
# ColumnProfile:
#     column_name: TLOC
#     type: FieldType.INTEGER
#
#     min: 3.0
#     max: 5207.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 685
#
#
#     Quantiles (est.):
#          0.1%: 3.0
#            1%: 7.091656874265572
#            5%: 7.0
#           25%: 17.50581395348837
#           50%: 51.925708699902245
#           75%: 129.13081752410113
#           95%: 439.51853146853097
#           99%: 974.5467272727275
#         99.9%: 2444.1052222222006
#
#     mean: 118.43379402585846
#     std: 219.9818379553363
#     variance: 48392.00903020784
#     skewness: 7.742571166792481
#     kurtosis: 111.32590123966531
#
# ColumnProfile:
#     column_name: CC_avg
#     type: FieldType.DECIMAL
#
#     min: 0.0
#     max: 41.1666666666667
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values:
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 1.6130329776204853
#           75%: 2.6207391268493194
#           95%: 4.895734321901286
#           99%: 8.080244416221035
#         99.9%: 18.46184318681302
#
#     mean: 1.9160172285053987
#     std: 1.8484725279596694
#     variance: 3.4168506866216113
#     skewness: 3.9915822752294794
#     kurtosis: 46.34493475597978
#
# ColumnProfile:
#     column_name: CC_max
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 310.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 74
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 1.0
#           50%: 3.0
#           75%: 7.0
#           95%: 18.827654320987648
#           99%: 36.02213235294118
#         99.9%: 145.4962857142821
#
#     mean: 5.620300193193629
#     std: 10.08126070140086
#     variance: 101.63181732960935
#     skewness: 12.068455534723485
#     kurtosis: 257.34828391052275
#
# ColumnProfile:
#     column_name: CC_sum
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1299.0
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 268
#
#
#     Quantiles (est.):
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 2.0
#           50%: 10.0
#           75%: 28.202639116202953
#           95%: 106.47045454545439
#           99%: 246.90803571428572
#         99.9%: 709.4838333333201
#
#     mean: 26.898944865507428
#     std: 57.05642023078911
#     variance: 3255.4350895524008
#     skewness: 8.140081331858646
#     kurtosis: 113.09353955468445
#
# ColumnProfile:
#     column_name: post
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 6729.0
#     missing_count: 0.0
#     not_missing_count: 6729.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#     unique_values: 2

# %%
#dflow_X = dflow_prepared.keep_columns(['pre','ACD','NBD_avg','NOF_avg','NOM_avg','NOT','NSF_avg','NSM_avg','PAR_avg'])
dflow_X = dflow_prepared.drop_columns('post')

dflow_y = dflow_prepared.keep_columns('post')

# %%
from sklearn.model_selection import train_test_split


x_df = dflow_X.to_pandas_dataframe()
y_df = dflow_y.to_pandas_dataframe()

x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2, random_state=223)
# flatten y_train to 1d array
y_train.values.flatten()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
automl_settings = {
    "iteration_timeout_minutes" : 60,
    "iterations" : 100,
    "primary_metric" : 'AUC_weighted',
    "preprocess" : True,
    "verbosity" : logging.INFO,
    "n_cross_validations": 100,
    "validation_size": 0.67,
    "enable_voting_ensemble":False,
    "enable_stack_ensemble":False
}

# %%
from azureml.train.automl import AutoMLConfig

# local compute 
automated_ml_config = AutoMLConfig(task = 'classification',
                             debug_log = 'automated_ml_errors.log',
                             path = project_folder,
                             X = x_train.values,
                             y = y_train.values.flatten(),
                             **automl_settings)

# %%
from azureml.core.experiment import Experiment
experiment=Experiment(ws, experiment_name)
local_run = experiment.submit(automated_ml_config, show_output=True)
# Out:
# Running on local machine
# Parent Run ID: AutoML_40519728-13ac-45f9-8190-5fe4bab075de
# Current status: DatasetFeaturization. Beginning to featurize the dataset.
# Current status: DatasetEvaluation. Gathering dataset statistics.
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturizationCompleted. Completed featurizing the dataset.
# Current status: DatasetCrossValidationSplit. Generating individually featurized CV splits.
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   StandardScalerWrapper SGD                      0:00:18       0.8255    0.8255
#          1   StandardScalerWrapper SGD                      0:00:15       0.8151    0.8255
#          2   MinMaxScaler LightGBM                          0:00:18       0.8301    0.8301
#          3   StandardScalerWrapper XGBoostClassifier        0:00:18       0.8304    0.8304
#          4   StandardScalerWrapper ExtremeRandomTrees       0:00:34       0.8088    0.8304
#          5   StandardScalerWrapper LightGBM                 0:00:21       0.8317    0.8317
#          6   StandardScalerWrapper SGD                      0:00:14       0.8146    0.8317
#          7   SparseNormalizer XGBoostClassifier             0:00:15       0.8040    0.8317
#          8   MinMaxScaler RandomForest                      0:00:22       0.8129    0.8317
#          9   StandardScalerWrapper SGD                      0:00:15       0.7947    0.8317
#         10   MinMaxScaler SGD                               0:00:15       0.7954    0.8317
#         11   StandardScalerWrapper XGBoostClassifier        0:00:20       0.8303    0.8317
#         12   MaxAbsScaler LightGBM                          0:00:16       0.8247    0.8317
#         13   MinMaxScaler LightGBM                          0:00:22       0.8303    0.8317
#         14   MinMaxScaler ExtremeRandomTrees                0:00:16       0.8155    0.8317
#         15   MinMaxScaler LightGBM                          0:00:16       0.8244    0.8317
#         16   StandardScalerWrapper BernoulliNaiveBayes      0:00:15       0.7678    0.8317
#         17   StandardScalerWrapper XGBoostClassifier        0:00:41       0.8302    0.8317
#         18   MaxAbsScaler LogisticRegression                0:00:20       0.8164    0.8317
#         19   StandardScalerWrapper XGBoostClassifier        0:03:23       0.8269    0.8317
#         20   RobustScaler LightGBM                          0:01:15       0.8319    0.8319
#         21   StandardScalerWrapper XGBoostClassifier        0:00:57       0.8324    0.8324
#         22   StandardScalerWrapper XGBoostClassifier        0:04:04       0.8245    0.8324
#         23   StandardScalerWrapper LightGBM                 0:00:46       0.8257    0.8324
#         24   StandardScalerWrapper LightGBM                 0:00:46       0.8238    0.8324
#         25   SparseNormalizer XGBoostClassifier             0:00:15       0.5000    0.8324
#         26   RobustScaler LogisticRegression                0:00:27       0.8181    0.8324
#         27   MaxAbsScaler LightGBM                          0:00:25       0.8311    0.8324
#         28   MaxAbsScaler GradientBoosting                  0:00:53       0.8101    0.8324
#         29   StandardScalerWrapper XGBoostClassifier        0:00:49       0.8176    0.8324
#         30   StandardScalerWrapper XGBoostClassifier        0:02:13       0.8015    0.8324
#         31   StandardScalerWrapper LightGBM                 0:00:24       0.8322    0.8324
#         32   StandardScalerWrapper LogisticRegression       0:00:21       0.8148    0.8324
#         33   MaxAbsScaler LightGBM                          0:00:34       0.8300    0.8324
#         34   StandardScalerWrapper LightGBM                 0:00:24       0.8285    0.8324
#         35   StandardScalerWrapper XGBoostClassifier        0:03:19       0.8060    0.8324
#         36   StandardScalerWrapper LightGBM                 0:00:53       0.8133    0.8324
#         37   MinMaxScaler LightGBM                          0:00:47       0.8158    0.8324
#         38   StandardScalerWrapper XGBoostClassifier        0:00:54       0.8221    0.8324
#         39   StandardScalerWrapper LightGBM                 0:01:23       0.8037    0.8324
#         40   StandardScalerWrapper XGBoostClassifier        0:00:35       0.8296    0.8324
#         41   MinMaxScaler LightGBM                          0:00:24       0.8281    0.8324
#         42   StandardScalerWrapper XGBoostClassifier        0:00:49       0.8307    0.8324
#         43   StandardScalerWrapper LightGBM                 0:01:01       0.8165    0.8324
#         44   MinMaxScaler LightGBM                          0:00:31       0.8322    0.8324
#         45   StandardScalerWrapper XGBoostClassifier        0:03:49       0.8049    0.8324
#         46   StandardScalerWrapper LightGBM                 0:00:47       0.8056    0.8324
#         47   RobustScaler LogisticRegression                0:00:33       0.7338    0.8324
#         48   StandardScalerWrapper LightGBM                 0:00:17       0.8253    0.8324
#         49   RobustScaler LightGBM                          0:00:25       0.8285    0.8324
#         50   StandardScalerWrapper XGBoostClassifier        0:00:23       0.8281    0.8324
#         51   StandardScalerWrapper LightGBM                 0:00:29       0.8177    0.8324
#         52   StandardScalerWrapper XGBoostClassifier        0:01:03       0.8187    0.8324
#         53   StandardScalerWrapper LightGBM                 0:00:24       0.8259    0.8324
#         54   StandardScalerWrapper LightGBM                 0:01:19       0.7972    0.8324
#         55   StandardScalerWrapper XGBoostClassifier        0:02:12       0.8260    0.8324
#         56   StandardScalerWrapper LightGBM                 0:00:50       0.8164    0.8324
#         57   StandardScalerWrapper XGBoostClassifier        0:00:50       0.8266    0.8324
#         60   StandardScalerWrapper XGBoostClassifier        0:01:01       0.8237    0.8324
#         61   StandardScalerWrapper XGBoostClassifier        0:01:06       0.8253    0.8324
#         62   StandardScalerWrapper LightGBM                 0:00:34       0.8222    0.8324
#         63   StandardScalerWrapper LightGBM                 0:00:41       0.8310    0.8324
#         64   StandardScalerWrapper LightGBM                 0:00:32       0.8195    0.8324
#         65   SparseNormalizer XGBoostClassifier             0:00:46       0.8286    0.8324
#         66   StandardScalerWrapper XGBoostClassifier        0:01:24       0.8328    0.8328
#         67   MinMaxScaler LightGBM                          0:01:08       0.8274    0.8328
#         68   MaxAbsScaler LightGBM                          0:00:40       0.8259    0.8328
#         69   RobustScaler LightGBM                          0:00:34       0.8220    0.8328
#         70   StandardScalerWrapper XGBoostClassifier        0:02:37       0.8128    0.8328
#         71   StandardScalerWrapper XGBoostClassifier        0:04:15       0.8015    0.8328
#         72   StandardScalerWrapper GradientBoosting         0:00:57       0.8286    0.8328
#         73   MaxAbsScaler LightGBM                          0:00:28       0.8273    0.8328
#         74   StandardScalerWrapper LightGBM                 0:00:54       0.8266    0.8328
#         75   StandardScalerWrapper XGBoostClassifier        0:00:36       0.8318    0.8328
#         76   StandardScalerWrapper LightGBM                 0:00:44       0.8156    0.8328
#         77   RobustScaler LightGBM                          0:00:21       0.8242    0.8328
#         78   StandardScalerWrapper XGBoostClassifier        0:01:08       0.8157    0.8328
#         79   StandardScalerWrapper LightGBM                 0:00:29       0.8209    0.8328
#         80   StandardScalerWrapper XGBoostClassifier        0:00:59       0.8237    0.8328
#         81   MaxAbsScaler LightGBM                          0:00:48       0.8280    0.8328
#         82   MinMaxScaler LightGBM                          0:00:21       0.8306    0.8328
#         83   StandardScalerWrapper LightGBM                 0:01:18       0.7993    0.8328
#         84   TruncatedSVDWrapper XGBoostClassifier          0:03:11       0.8209    0.8328
#         85   StandardScalerWrapper XGBoostClassifier        0:00:28       0.8329    0.8329
#         86   StandardScalerWrapper XGBoostClassifier        0:01:02       0.8291    0.8329
#         87   MaxAbsScaler LightGBM                          0:00:45       0.8233    0.8329
#         88   MinMaxScaler LightGBM                          0:01:04       0.8230    0.8329
#         89   StandardScalerWrapper LightGBM                 0:00:38       0.8192    0.8329
#         90   StandardScalerWrapper XGBoostClassifier        0:01:59       0.8118    0.8329
#         91   MaxAbsScaler LightGBM                          0:00:23       0.8194    0.8329
#         92   StandardScalerWrapper XGBoostClassifier        0:01:08       0.8198    0.8329
#         93   StandardScalerWrapper LightGBM                 0:00:41       0.8098    0.8329
#         94   MinMaxScaler LightGBM                          0:00:31       0.8293    0.8329
#         95   StandardScalerWrapper XGBoostClassifier        0:00:35       0.8290    0.8329
#         96   MinMaxScaler LightGBM                          0:00:19       0.8301    0.8329
#         97   RobustScaler LightGBM                          0:00:33       0.8177    0.8329
#         98   MaxAbsScaler GradientBoosting                  0:00:34       0.8281    0.8329
#         99   StandardScalerWrapper XGBoostClassifier        0:00:36       0.8316    0.8329

# %%
from azureml.widgets import RunDetails
RunDetails(local_run).show()

# %%
from azureml.widgets import RunDetails
from azureml.train.automl.run import AutoMLRun

experiment=Experiment(ws, experiment_name)

remote_run = AutoMLRun(experiment = experiment, run_id ="AutoML_0aa2549d-3478-4b7a-a196-1dc3e0be864b")

RunDetails(remote_run).show()

# %%
# but we don't use voting ensemble
best_run, fitted_model = remote_run.get_output()
print(best_run)

print(fitted_model)

# %%
iteration = 91
b_run, b_model = remote_run.get_output(iteration=iteration)
print(b_run)
print(b_model)

# %%
type(fitted_model)

# %%
best_run, fitted_model = local_run.get_output()
print(best_run)
print(fitted_model)

# %%
fitted_model.predict

# %%
y_predict = fitted_model.predict(x_test.values) 
print(y_predict[:10])

# %%
y_actual = y_test.values.flatten().tolist()
y_actual[:10]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_actual, y_predict)

# %%
from sklearn.metrics import precision_recall_fscore_support
precision ,recall ,fbeta_score ,support=precision_recall_fscore_support(y_actual, y_predict,average='binary')
print('precision:'+str(precision)+'\nrecall:'+str(recall))
